# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from PIL import Image
import os
import shutil
import matplotlib.pyplot as plt

# %%
os.chdir('../')

# %% [markdown]
# # Understanding Benign Data

# %%
BATCH_SIZE=16

# %%
im = Image.open('data/benign/img/1.png')
# im.show()
image_size = np.array(im).shape
image_size
# Out:
# (471, 562, 3)

# %%
# im.show()
im2 = im.crop((57,0,505,448))
# im2.show()
im2=np.array(im2)/255.
im2.shape
# im2[0] = [np.mean(im2[0])]
im2[:,:,0].shape
# Out:
# (448, 448)

# %%
# os.mkdir('delete/')
# shutil.move('garbage.txt', 'delete/garbage.txt')

# %%
data_path_img = 'data/normal/'

def refactor_path(data_path):
    if not os.path.exists(data_path+'img/'):
        os.mkdir(data_path+'img/')
    if not os.path.exists(data_path+'mask/'):
        os.mkdir(data_path+'mask/')

    for file in os.listdir(data_path):
        if file[-3:] == 'png':
            if file[-8:-4] == 'mask':
                num = file.split('(')
                num = int(num[1].split(')')[0])
                shutil.move(f'{data_path}{file}', f'{data_path}mask/{num}.png')
            else:
                num = file.split('(')
                num = int(num[1].split(')')[0])
                shutil.move(f'{data_path}{file}', f'{data_path}img/{num}.png')

# refactor_path(data_path_img)

# %%
data_path_img = 'data/benign/img/'
data_path_mask = 'data/benign/mask/'


for file in os.listdir(data_path_img):
    im = Image.open(data_path_img+file)
    im = np.array(im)
    # print(f"file: {len(im.shape)}")
    if len(im.shape) == 3 and im.shape[2]==4:
        print(f"delete: {file}")
        os.remove(data_path_img+file)
        os.remove(data_path_mask+file)


# files = ["163.png",
# "173.png",
# "98.png",
# "100.png",
# "315.png",
# "181.png",
# "83.png",
# "93.png"]
# for file in files:
#     print(f"delete: {data_path_mask+file}")
#     os.remove(data_path_mask+file)

# %%
data_path_img = 'data/benign/img/'

# %%
class CustomDataGenerator(tf.keras.utils.Sequence):

    def __init__(self, df, X_col, y_col, batch_size=32, shuffle=False):
        self.df = df.copy()
        self.X_col = X_col
        self.y_col = y_col
        self.batch_size = batch_size
        self.shuffle = shuffle

        self.n = len(self.df)


    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
    

    def __get_input(self, paths):
        out = []

        for path in paths:
            im = Image.open(path)
            im = im.crop((57,0,505,448))
            im = np.array(im)/255.

            out.append(im)

        return out


    def __get_output(self, labels):
        out = []

        for label in labels:
            im = Image.open(label)
            im = im.crop((57,0,505,448))
            im = np.array(im)/1.
            im = im.reshape((448,448,1))
            # im = np.broadcast_to(im,(448,448,3))
            
            # print('out', im.shape)
            # im = im[:,:,0]
            
            out.append(im)

        return out


    def __get_data(self, batches):
        paths = batches[self.X_col]
        X = self.__get_input(paths)
        labels = batches[self.y_col]
        y = self.__get_output(labels)
        X = np.array(X, dtype=object)
        y = np.array(y, dtype=object)
        X = tf.convert_to_tensor(X, dtype=tf.float32)
        y = tf.convert_to_tensor(y, dtype=tf.float32)
        return X,y


    def __getitem__(self, index):
        batches = self.df.iloc[index*self.batch_size:(index+1)*self.batch_size]
        X,y = self.__get_data(batches)
        return X,y


    def __len__(self):
        return self.n // self.batch_size

# %%
img_path = 'data/benign/img/'
img_files = os.listdir(img_path)
img_files = [img_path+i for i in img_files]

mask_path = 'data/benign/mask/'
mask_files = os.listdir(mask_path)
mask_files = [mask_path+i for i in mask_files]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    img_files, mask_files,
    test_size=.33,
    random_state=42
)

train_df = pd.DataFrame({'img':X_train, 'labels':y_train})
val_df = pd.DataFrame({'img':X_test, 'labels':y_test})
train_df, val_df
# Out:
# (                         img                    labels
#  0    data/benign/img/224.png  data/benign/mask/224.png
#  1    data/benign/img/280.png  data/benign/mask/280.png
#  2    data/benign/img/421.png  data/benign/mask/421.png
#  3    data/benign/img/130.png  data/benign/mask/130.png
#  4    data/benign/img/403.png  data/benign/mask/403.png
#  ..                       ...                       ...
#  281   data/benign/img/58.png   data/benign/mask/58.png
#  282  data/benign/img/364.png  data/benign/mask/364.png
#  283   data/benign/img/31.png   data/benign/mask/31.png
#  284  data/benign/img/431.png  data/benign/mask/431.png
#  285  data/benign/img/166.png  data/benign/mask/166.png
#
#  [286 rows x 2 columns],
#                           img                    labels
#  0    data/benign/img/153.png  data/benign/mask/153.png
#  1    data/benign/img/398.png  data/benign/mask/398.png
#  2     data/benign/img/38.png   data/benign/mask/38.png
#  3    data/benign/img/411.png  data/benign/mask/411.png
#  4    data/benign/img/179.png  data/benign/mask/179.png
#  ..                       ...                       ...
#  137   data/benign/img/84.png   data/benign/mask/84.png
#  138  data/benign/img/144.png  data/benign/mask/144.png
#  139  data/benign/img/259.png  data/benign/mask/259.png
#  140  data/benign/img/111.png  data/benign/mask/111.png
#  141  data/benign/img/317.png  data/benign/mask/317.png
#
#  [142 rows x 2 columns])

# %%
traingen = CustomDataGenerator(train_df, 'img', 'labels', BATCH_SIZE)
valgen = CustomDataGenerator(val_df, 'img', 'labels', BATCH_SIZE)
traingen, valgen
# Out:
# (<__main__.CustomDataGenerator at 0x29a2ae3d0>,
#  <__main__.CustomDataGenerator at 0x29a2ae2e0>)

# %%
# len(traingen.__getitem__(0)[0])
len(traingen.__getitem__(0)[1])
# c = 0
# for data in traingen:
#     print(c, len(data))
#     c += 1
# Out:
# 16

# %%
# traingen.__getitem__(11)[0][4][0][1]

# %% [markdown]
# # UNet model

# %%
from models.unet import UNet

model = UNet((448,448,3))
model

# %%
model.summary()
# Out:
# Model: "U-net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 448, 448, 3  0           []
#                                 )]
#
#  conv2d_20 (Conv2D)             (None, 448, 448, 64  1792        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 448, 448, 64  256        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 448, 448, 64  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 224, 224, 64  0          ['activation_19[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 224, 224, 12  73856       ['max_pooling2d_4[0][0]']
#                                 8)
#
#  batch_normalization_21 (BatchN  (None, 224, 224, 12  512        ['conv2d_22[0][0]']
#  ormalization)                  8)
#
#  activation_21 (Activation)     (None, 224, 224, 12  0           ['batch_normalization_21[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 112, 112, 12  0          ['activation_21[0][0]']
#                                 8)
#
#  conv2d_24 (Conv2D)             (None, 112, 112, 25  295168      ['max_pooling2d_5[0][0]']
#                                 6)
#
#  batch_normalization_23 (BatchN  (None, 112, 112, 25  1024       ['conv2d_24[0][0]']
#  ormalization)                  6)
#
#  activation_23 (Activation)     (None, 112, 112, 25  0           ['batch_normalization_23[0][0]']
#                                 6)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 56, 56, 256)  0          ['activation_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 56, 56, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 56, 56, 512)  2048       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 56, 56, 512)  0           ['batch_normalization_25[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 28, 28, 512)  0          ['activation_25[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 28, 28, 1024  4719616     ['max_pooling2d_7[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 28, 28, 1024  4096       ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  activation_27 (Activation)     (None, 28, 28, 1024  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 56, 56, 512)  2097664    ['activation_27[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 56, 56, 1024  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'activation_25[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 56, 56, 3)    27651       ['concatenate_4[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 56, 56, 3)   12          ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 56, 56, 3)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 112, 112, 25  3328       ['activation_29[0][0]']
#  spose)                         6)
#
#  concatenate_5 (Concatenate)    (None, 112, 112, 51  0           ['conv2d_transpose_5[0][0]',
#                                 2)                                'activation_23[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 112, 112, 3)  13827       ['concatenate_5[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 112, 112, 3)  12         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 112, 112, 3)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 224, 224, 12  1664       ['activation_31[0][0]']
#  spose)                         8)
#
#  concatenate_6 (Concatenate)    (None, 224, 224, 25  0           ['conv2d_transpose_6[0][0]',
#                                 6)                                'activation_21[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 224, 224, 3)  6915        ['concatenate_6[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 224, 224, 3)  12         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 224, 224, 3)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 448, 448, 64  832        ['activation_33[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 448, 448, 12  0           ['conv2d_transpose_7[0][0]',
#                                 8)                                'activation_19[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 448, 448, 3)  3459        ['concatenate_7[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 448, 448, 3)  12         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 448, 448, 3)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 448, 448, 1)  4           ['activation_35[0][0]']
#
# ==================================================================================================
# Total params: 8,433,920
# Trainable params: 8,429,928
# Non-trainable params: 3,992
# __________________________________________________________________________________________________

# %%
class DiceLoss(tf.keras.losses.Loss):
    def __init__(self, smooth=1e-6, gama=2):
        super(DiceLoss, self).__init__()
        self.name = 'NDL'
        self.smooth = smooth
        self.gama = gama

    def call(self, y_true, y_pred):
        y_true, y_pred = tf.cast(
            y_true, dtype=tf.float32), tf.cast(y_pred, tf.float32)
        nominator = 2 * \
            tf.reduce_sum(tf.multiply(y_pred, y_true)) + self.smooth
        denominator = tf.reduce_sum(
            y_pred ** self.gama) + tf.reduce_sum(y_true ** self.gama) + self.smooth
        result = 1 - tf.divide(nominator, denominator)
        return result

# %%
if os.path.exists('checkpoints/unet_best_0.04779/'):
    print('weights loaded')
    model.load_weights('checkpoints/unet_best_0.04779/')

opt = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    epsilon=1e-07,
)

# loss = tf.keras.losses.BinaryCrossentropy()
loss = DiceLoss()

model.compile(
    optimizer=opt,
    loss=loss,
    # metrics=['accuracy']
)
# Out:
# weights loaded

# %%
EPOCHS = 1

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'checkpoints/unet',
    verbose=1,
    monitor='loss',
    save_best_only=True
)

lr_reduction = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='loss',
    factor=0.5,
    patience=10,
    verbose=1,
    min_delta=0.0001,
    cooldown=3,
    min_lr=1e-8,
)

model.fit(
    traingen,
    epochs=EPOCHS,
    verbose=1,
    # validation_data=valgen,
    callbacks=[checkpoint, lr_reduction]
)
# Out:
# 17/17 [==============================] - ETA: 0s - loss: 0.0435
# Epoch 1: loss improved from inf to 0.04350, saving model to checkpoints/unet
# INFO:tensorflow:Assets written to: checkpoints/unet/assets
# 17/17 [==============================] - 32s 2s/step - loss: 0.0435 - lr: 0.0010

# %%
model.load_weights('checkpoints/unet_best_0.04779/') # 0.04779

# %%
test = valgen.__getitem__(0)
img = test[0][6]
mask = test[1][6]

# %%
img.shape, mask.shape
# Out:
# (TensorShape([448, 448, 3]), TensorShape([448, 448, 1]))

# %%
from matplotlib import pyplot as plt
plt.imshow(img, interpolation='nearest')
plt.show()

# %%
plt.imshow(mask, cmap='gray')
plt.show()

# %%
pred = model.predict(tf.convert_to_tensor([img]))
pred = pred[0]

def fn(x):
    return 0. if x < 0.5 else 1.
fn = np.vectorize(fn)
pred = fn(pred)
# min(np.unique(pred))

# %%
plt.imshow(pred, cmap='gray')
plt.show()

# %% [markdown]
# # Enet experimentation

# %%
from enet import ENet

model = ENet(n_classes=1, input_height=448, input_width=448)
model

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 448, 448, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 224, 224, 13  364         ['input_2[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 224, 224, 3)  0          ['input_2[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 224, 224, 16  0           ['conv2d_19[0][0]',
#                                 )                                 'max_pooling2d_4[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 224, 224, 16  64         ['concatenate_4[0][0]']
#  ormalization)                  )
#
#  p_re_lu (PReLU)                (None, 224, 224, 16  16          ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 112, 112, 16  1024        ['p_re_lu[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 112, 112, 16  64         ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  p_re_lu_1 (PReLU)              (None, 112, 112, 16  16          ['batch_normalization_19[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 112, 112, 16  2320        ['p_re_lu_1[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 112, 112, 16  64         ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  p_re_lu_2 (PReLU)              (None, 112, 112, 16  16          ['batch_normalization_20[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 112, 112, 16  0          ['p_re_lu[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 112, 112, 64  1024        ['p_re_lu_2[0][0]']
#                                 )
#
#  permute (Permute)              (None, 112, 16, 112  0           ['max_pooling2d_5[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 112, 112, 64  256        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  zero_padding2d (ZeroPadding2D)  (None, 112, 64, 112  0          ['permute[0][0]']
#                                 )
#
#  spatial_dropout2d (SpatialDrop  (None, 112, 112, 64  0          ['batch_normalization_21[0][0]']
#  out2D)                         )
#
#  permute_1 (Permute)            (None, 112, 112, 64  0           ['zero_padding2d[0][0]']
#                                 )
#
#  add (Add)                      (None, 112, 112, 64  0           ['spatial_dropout2d[0][0]',
#                                 )                                 'permute_1[0][0]']
#
#  p_re_lu_3 (PReLU)              (None, 112, 112, 64  64          ['add[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 112, 112, 16  1024        ['p_re_lu_3[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 112, 112, 16  64         ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  p_re_lu_4 (PReLU)              (None, 112, 112, 16  16          ['batch_normalization_22[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 112, 112, 16  2320        ['p_re_lu_4[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 112, 112, 16  64         ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  p_re_lu_5 (PReLU)              (None, 112, 112, 16  16          ['batch_normalization_23[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 112, 112, 64  1024        ['p_re_lu_5[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 112, 112, 64  256        ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  spatial_dropout2d_1 (SpatialDr  (None, 112, 112, 64  0          ['batch_normalization_24[0][0]']
#  opout2D)                       )
#
#  add_1 (Add)                    (None, 112, 112, 64  0           ['spatial_dropout2d_1[0][0]',
#                                 )                                 'p_re_lu_3[0][0]']
#
#  p_re_lu_6 (PReLU)              (None, 112, 112, 64  64          ['add_1[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 112, 112, 16  1024        ['p_re_lu_6[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 112, 112, 16  64         ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  p_re_lu_7 (PReLU)              (None, 112, 112, 16  16          ['batch_normalization_25[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 112, 112, 16  2320        ['p_re_lu_7[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 112, 112, 16  64         ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  p_re_lu_8 (PReLU)              (None, 112, 112, 16  16          ['batch_normalization_26[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 112, 112, 64  1024        ['p_re_lu_8[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 112, 112, 64  256        ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  spatial_dropout2d_2 (SpatialDr  (None, 112, 112, 64  0          ['batch_normalization_27[0][0]']
#  opout2D)                       )
#
#  add_2 (Add)                    (None, 112, 112, 64  0           ['spatial_dropout2d_2[0][0]',
#                                 )                                 'p_re_lu_6[0][0]']
#
#  p_re_lu_9 (PReLU)              (None, 112, 112, 64  64          ['add_2[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 112, 112, 16  1024        ['p_re_lu_9[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 112, 112, 16  64         ['conv2d_29[0][0]']
#  ormalization)                  )
#
#  p_re_lu_10 (PReLU)             (None, 112, 112, 16  16          ['batch_normalization_28[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 112, 112, 16  2320        ['p_re_lu_10[0][0]']
#                                 )
#
#  batch_normalization_29 (BatchN  (None, 112, 112, 16  64         ['conv2d_30[0][0]']
#  ormalization)                  )
#
#  p_re_lu_11 (PReLU)             (None, 112, 112, 16  16          ['batch_normalization_29[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 112, 112, 64  1024        ['p_re_lu_11[0][0]']
#                                 )
#
#  batch_normalization_30 (BatchN  (None, 112, 112, 64  256        ['conv2d_31[0][0]']
#  ormalization)                  )
#
#  spatial_dropout2d_3 (SpatialDr  (None, 112, 112, 64  0          ['batch_normalization_30[0][0]']
#  opout2D)                       )
#
#  add_3 (Add)                    (None, 112, 112, 64  0           ['spatial_dropout2d_3[0][0]',
#                                 )                                 'p_re_lu_9[0][0]']
#
#  p_re_lu_12 (PReLU)             (None, 112, 112, 64  64          ['add_3[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 112, 112, 16  1024        ['p_re_lu_12[0][0]']
#                                 )
#
#  batch_normalization_31 (BatchN  (None, 112, 112, 16  64         ['conv2d_32[0][0]']
#  ormalization)                  )
#
#  p_re_lu_13 (PReLU)             (None, 112, 112, 16  16          ['batch_normalization_31[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 112, 112, 16  2320        ['p_re_lu_13[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 112, 112, 16  64         ['conv2d_33[0][0]']
#  ormalization)                  )
#
#  p_re_lu_14 (PReLU)             (None, 112, 112, 16  16          ['batch_normalization_32[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 112, 112, 64  1024        ['p_re_lu_14[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 112, 112, 64  256        ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  spatial_dropout2d_4 (SpatialDr  (None, 112, 112, 64  0          ['batch_normalization_33[0][0]']
#  opout2D)                       )
#
#  add_4 (Add)                    (None, 112, 112, 64  0           ['spatial_dropout2d_4[0][0]',
#                                 )                                 'p_re_lu_12[0][0]']
#
#  p_re_lu_15 (PReLU)             (None, 112, 112, 64  64          ['add_4[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 56, 56, 32)   8192        ['p_re_lu_15[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 56, 56, 32)  128         ['conv2d_35[0][0]']
#  ormalization)
#
#  p_re_lu_16 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_34[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 56, 56, 32)   9248        ['p_re_lu_16[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 56, 56, 32)  128         ['conv2d_36[0][0]']
#  ormalization)
#
#  p_re_lu_17 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_35[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 56, 56, 64)  0           ['p_re_lu_15[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 56, 56, 128)  4096        ['p_re_lu_17[0][0]']
#
#  permute_2 (Permute)            (None, 56, 64, 56)   0           ['max_pooling2d_6[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 56, 56, 128)  512        ['conv2d_37[0][0]']
#  ormalization)
#
#  zero_padding2d_1 (ZeroPadding2  (None, 56, 128, 56)  0          ['permute_2[0][0]']
#  D)
#
#  spatial_dropout2d_5 (SpatialDr  (None, 56, 56, 128)  0          ['batch_normalization_36[0][0]']
#  opout2D)
#
#  permute_3 (Permute)            (None, 56, 56, 128)  0           ['zero_padding2d_1[0][0]']
#
#  add_5 (Add)                    (None, 56, 56, 128)  0           ['spatial_dropout2d_5[0][0]',
#                                                                   'permute_3[0][0]']
#
#  p_re_lu_18 (PReLU)             (None, 56, 56, 128)  128         ['add_5[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 56, 56, 32)   4096        ['p_re_lu_18[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 56, 56, 32)  128         ['conv2d_38[0][0]']
#  ormalization)
#
#  p_re_lu_19 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 56, 56, 32)   9248        ['p_re_lu_19[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 56, 56, 32)  128         ['conv2d_39[0][0]']
#  ormalization)
#
#  p_re_lu_20 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_38[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 56, 56, 128)  4096        ['p_re_lu_20[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 56, 56, 128)  512        ['conv2d_40[0][0]']
#  ormalization)
#
#  spatial_dropout2d_6 (SpatialDr  (None, 56, 56, 128)  0          ['batch_normalization_39[0][0]']
#  opout2D)
#
#  add_6 (Add)                    (None, 56, 56, 128)  0           ['spatial_dropout2d_6[0][0]',
#                                                                   'p_re_lu_18[0][0]']
#
#  p_re_lu_21 (PReLU)             (None, 56, 56, 128)  128         ['add_6[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 56, 56, 32)   4096        ['p_re_lu_21[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 56, 56, 32)  128         ['conv2d_41[0][0]']
#  ormalization)
#
#  p_re_lu_22 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_40[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 56, 56, 32)   9248        ['p_re_lu_22[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 56, 56, 32)  128         ['conv2d_42[0][0]']
#  ormalization)
#
#  p_re_lu_23 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 56, 56, 128)  4096        ['p_re_lu_23[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 56, 56, 128)  512        ['conv2d_43[0][0]']
#  ormalization)
#
#  spatial_dropout2d_7 (SpatialDr  (None, 56, 56, 128)  0          ['batch_normalization_42[0][0]']
#  opout2D)
#
#  add_7 (Add)                    (None, 56, 56, 128)  0           ['spatial_dropout2d_7[0][0]',
#                                                                   'p_re_lu_21[0][0]']
#
#  p_re_lu_24 (PReLU)             (None, 56, 56, 128)  128         ['add_7[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 56, 56, 32)   4096        ['p_re_lu_24[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 56, 56, 32)  128         ['conv2d_44[0][0]']
#  ormalization)
#
#  p_re_lu_25 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_43[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 56, 56, 32)   5120        ['p_re_lu_25[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 56, 56, 32)   5152        ['conv2d_45[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 56, 56, 32)  128         ['conv2d_46[0][0]']
#  ormalization)
#
#  p_re_lu_26 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_44[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 56, 56, 128)  4096        ['p_re_lu_26[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 56, 56, 128)  512        ['conv2d_47[0][0]']
#  ormalization)
#
#  spatial_dropout2d_8 (SpatialDr  (None, 56, 56, 128)  0          ['batch_normalization_45[0][0]']
#  opout2D)
#
#  add_8 (Add)                    (None, 56, 56, 128)  0           ['spatial_dropout2d_8[0][0]',
#                                                                   'p_re_lu_24[0][0]']
#
#  p_re_lu_27 (PReLU)             (None, 56, 56, 128)  128         ['add_8[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 56, 56, 32)   4096        ['p_re_lu_27[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 56, 56, 32)  128         ['conv2d_48[0][0]']
#  ormalization)
#
#  p_re_lu_28 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_46[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 56, 56, 32)   9248        ['p_re_lu_28[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 56, 56, 32)  128         ['conv2d_49[0][0]']
#  ormalization)
#
#  p_re_lu_29 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_47[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 56, 56, 128)  4096        ['p_re_lu_29[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 56, 56, 128)  512        ['conv2d_50[0][0]']
#  ormalization)
#
#  spatial_dropout2d_9 (SpatialDr  (None, 56, 56, 128)  0          ['batch_normalization_48[0][0]']
#  opout2D)
#
#  add_9 (Add)                    (None, 56, 56, 128)  0           ['spatial_dropout2d_9[0][0]',
#                                                                   'p_re_lu_27[0][0]']
#
#  p_re_lu_30 (PReLU)             (None, 56, 56, 128)  128         ['add_9[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 56, 56, 32)   4096        ['p_re_lu_30[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 56, 56, 32)  128         ['conv2d_51[0][0]']
#  ormalization)
#
#  p_re_lu_31 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_49[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 56, 56, 32)   9248        ['p_re_lu_31[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 56, 56, 32)  128         ['conv2d_52[0][0]']
#  ormalization)
#
#  p_re_lu_32 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_50[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 56, 56, 128)  4096        ['p_re_lu_32[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 56, 56, 128)  512        ['conv2d_53[0][0]']
#  ormalization)
#
#  spatial_dropout2d_10 (SpatialD  (None, 56, 56, 128)  0          ['batch_normalization_51[0][0]']
#  ropout2D)
#
#  add_10 (Add)                   (None, 56, 56, 128)  0           ['spatial_dropout2d_10[0][0]',
#                                                                   'p_re_lu_30[0][0]']
#
#  p_re_lu_33 (PReLU)             (None, 56, 56, 128)  128         ['add_10[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 56, 56, 32)   4096        ['p_re_lu_33[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 56, 56, 32)  128         ['conv2d_54[0][0]']
#  ormalization)
#
#  p_re_lu_34 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_52[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 56, 56, 32)   9248        ['p_re_lu_34[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 56, 56, 32)  128         ['conv2d_55[0][0]']
#  ormalization)
#
#  p_re_lu_35 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_53[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 56, 56, 128)  4096        ['p_re_lu_35[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 56, 56, 128)  512        ['conv2d_56[0][0]']
#  ormalization)
#
#  spatial_dropout2d_11 (SpatialD  (None, 56, 56, 128)  0          ['batch_normalization_54[0][0]']
#  ropout2D)
#
#  add_11 (Add)                   (None, 56, 56, 128)  0           ['spatial_dropout2d_11[0][0]',
#                                                                   'p_re_lu_33[0][0]']
#
#  p_re_lu_36 (PReLU)             (None, 56, 56, 128)  128         ['add_11[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 56, 56, 32)   4096        ['p_re_lu_36[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 56, 56, 32)  128         ['conv2d_57[0][0]']
#  ormalization)
#
#  p_re_lu_37 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_55[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 56, 56, 32)   5120        ['p_re_lu_37[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 56, 56, 32)   5152        ['conv2d_58[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 56, 56, 32)  128         ['conv2d_59[0][0]']
#  ormalization)
#
#  p_re_lu_38 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_56[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 56, 56, 128)  4096        ['p_re_lu_38[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 56, 56, 128)  512        ['conv2d_60[0][0]']
#  ormalization)
#
#  spatial_dropout2d_12 (SpatialD  (None, 56, 56, 128)  0          ['batch_normalization_57[0][0]']
#  ropout2D)
#
#  add_12 (Add)                   (None, 56, 56, 128)  0           ['spatial_dropout2d_12[0][0]',
#                                                                   'p_re_lu_36[0][0]']
#
#  p_re_lu_39 (PReLU)             (None, 56, 56, 128)  128         ['add_12[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 56, 56, 32)   4096        ['p_re_lu_39[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 56, 56, 32)  128         ['conv2d_61[0][0]']
#  ormalization)
#
#  p_re_lu_40 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_58[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 56, 56, 32)   9248        ['p_re_lu_40[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 56, 56, 32)  128         ['conv2d_62[0][0]']
#  ormalization)
#
#  p_re_lu_41 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_59[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 56, 56, 128)  4096        ['p_re_lu_41[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 56, 56, 128)  512        ['conv2d_63[0][0]']
#  ormalization)
#
#  spatial_dropout2d_13 (SpatialD  (None, 56, 56, 128)  0          ['batch_normalization_60[0][0]']
#  ropout2D)
#
#  add_13 (Add)                   (None, 56, 56, 128)  0           ['spatial_dropout2d_13[0][0]',
#                                                                   'p_re_lu_39[0][0]']
#
#  p_re_lu_42 (PReLU)             (None, 56, 56, 128)  128         ['add_13[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 56, 56, 32)   4096        ['p_re_lu_42[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 56, 56, 32)  128         ['conv2d_64[0][0]']
#  ormalization)
#
#  p_re_lu_43 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_61[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 56, 56, 32)   9248        ['p_re_lu_43[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 56, 56, 32)  128         ['conv2d_65[0][0]']
#  ormalization)
#
#  p_re_lu_44 (PReLU)             (None, 56, 56, 32)   32          ['batch_normalization_62[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 56, 56, 128)  4096        ['p_re_lu_44[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 56, 56, 128)  512        ['conv2d_66[0][0]']
#  ormalization)
#
#  spatial_dropout2d_14 (SpatialD  (None, 56, 56, 128)  0          ['batch_normalization_63[0][0]']
#  ropout2D)
#
#  add_14 (Add)                   (None, 56, 56, 128)  0           ['spatial_dropout2d_14[0][0]',
#                                                                   'p_re_lu_42[0][0]']
#
#  p_re_lu_45 (PReLU)             (None, 56, 56, 128)  128         ['add_14[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 56, 56, 32)   4096        ['p_re_lu_45[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 56, 56, 32)  128         ['conv2d_67[0][0]']
#  ormalization)
# ...
#  activation_18 (Activation)     (None, 56, 56, 16)   0           ['batch_normalization_85[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 112, 112, 16  2320       ['activation_18[0][0]']
#  spose)                         )
#
#  batch_normalization_86 (BatchN  (None, 112, 112, 16  64         ['conv2d_transpose_4[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 112, 112, 16  0           ['batch_normalization_86[0][0]']
#                                 )
#
#  conv2d_92 (Conv2D)             (None, 56, 56, 64)   8192        ['p_re_lu_66[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 112, 112, 64  1024        ['activation_19[0][0]']
#                                 )
#
#  batch_normalization_87 (BatchN  (None, 56, 56, 64)  256         ['conv2d_92[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 112, 112, 64  256        ['conv2d_91[0][0]']
#  ormalization)                  )
#
#  up_sampling2d (UpSampling2D)   (None, 112, 112, 64  0           ['batch_normalization_87[0][0]']
#                                 )
#
#  add_22 (Add)                   (None, 112, 112, 64  0           ['batch_normalization_88[0][0]',
#                                 )                                 'up_sampling2d[0][0]']
#
#  activation_20 (Activation)     (None, 112, 112, 64  0           ['add_22[0][0]']
#                                 )
#
#  conv2d_93 (Conv2D)             (None, 112, 112, 16  1024        ['activation_20[0][0]']
#                                 )
#
#  batch_normalization_89 (BatchN  (None, 112, 112, 16  64         ['conv2d_93[0][0]']
#  ormalization)                  )
#
#  activation_21 (Activation)     (None, 112, 112, 16  0           ['batch_normalization_89[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 112, 112, 16  2320        ['activation_21[0][0]']
#                                 )
#
#  batch_normalization_90 (BatchN  (None, 112, 112, 16  64         ['conv2d_94[0][0]']
#  ormalization)                  )
#
#  activation_22 (Activation)     (None, 112, 112, 16  0           ['batch_normalization_90[0][0]']
#                                 )
#
#  conv2d_95 (Conv2D)             (None, 112, 112, 64  1024        ['activation_22[0][0]']
#                                 )
#
#  batch_normalization_91 (BatchN  (None, 112, 112, 64  256        ['conv2d_95[0][0]']
#  ormalization)                  )
#
#  add_23 (Add)                   (None, 112, 112, 64  0           ['batch_normalization_91[0][0]',
#                                 )                                 'activation_20[0][0]']
#
#  activation_23 (Activation)     (None, 112, 112, 64  0           ['add_23[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 112, 112, 16  1024        ['activation_23[0][0]']
#                                 )
#
#  batch_normalization_92 (BatchN  (None, 112, 112, 16  64         ['conv2d_96[0][0]']
#  ormalization)                  )
#
#  activation_24 (Activation)     (None, 112, 112, 16  0           ['batch_normalization_92[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 112, 112, 16  2320        ['activation_24[0][0]']
#                                 )
#
#  batch_normalization_93 (BatchN  (None, 112, 112, 16  64         ['conv2d_97[0][0]']
#  ormalization)                  )
#
#  activation_25 (Activation)     (None, 112, 112, 16  0           ['batch_normalization_93[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 112, 112, 64  1024        ['activation_25[0][0]']
#                                 )
#
#  batch_normalization_94 (BatchN  (None, 112, 112, 64  256        ['conv2d_98[0][0]']
#  ormalization)                  )
#
#  add_24 (Add)                   (None, 112, 112, 64  0           ['batch_normalization_94[0][0]',
#                                 )                                 'activation_23[0][0]']
#
#  activation_26 (Activation)     (None, 112, 112, 64  0           ['add_24[0][0]']
#                                 )
#
#  conv2d_99 (Conv2D)             (None, 112, 112, 4)  256         ['activation_26[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 112, 112, 4)  16         ['conv2d_99[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 112, 112, 4)  0           ['batch_normalization_95[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 224, 224, 4)  148        ['activation_27[0][0]']
#  spose)
#
#  batch_normalization_96 (BatchN  (None, 224, 224, 4)  16         ['conv2d_transpose_5[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 224, 224, 4)  0           ['batch_normalization_96[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 112, 112, 16  1024        ['activation_26[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 224, 224, 16  64          ['activation_28[0][0]']
#                                 )
#
#  batch_normalization_97 (BatchN  (None, 112, 112, 16  64         ['conv2d_101[0][0]']
#  ormalization)                  )
#
#  batch_normalization_98 (BatchN  (None, 224, 224, 16  64         ['conv2d_100[0][0]']
#  ormalization)                  )
#
#  up_sampling2d_1 (UpSampling2D)  (None, 224, 224, 16  0          ['batch_normalization_97[0][0]']
#                                 )
#
#  add_25 (Add)                   (None, 224, 224, 16  0           ['batch_normalization_98[0][0]',
#                                 )                                 'up_sampling2d_1[0][0]']
#
#  activation_29 (Activation)     (None, 224, 224, 16  0           ['add_25[0][0]']
#                                 )
#
#  conv2d_102 (Conv2D)            (None, 224, 224, 4)  64          ['activation_29[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 224, 224, 4)  16         ['conv2d_102[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 224, 224, 4)  0           ['batch_normalization_99[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 224, 224, 4)  148         ['activation_30[0][0]']
#
#  batch_normalization_100 (Batch  (None, 224, 224, 4)  16         ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_31 (Activation)     (None, 224, 224, 4)  0           ['batch_normalization_100[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 224, 224, 16  64          ['activation_31[0][0]']
#                                 )
#
#  batch_normalization_101 (Batch  (None, 224, 224, 16  64         ['conv2d_104[0][0]']
#  Normalization)                 )
#
#  add_26 (Add)                   (None, 224, 224, 16  0           ['batch_normalization_101[0][0]',
#                                 )                                 'activation_29[0][0]']
#
#  activation_32 (Activation)     (None, 224, 224, 16  0           ['add_26[0][0]']
#                                 )
#
#  conv2d_transpose_6 (Conv2DTran  (None, 448, 448, 1)  65         ['activation_32[0][0]']
#  spose)
#
#  activation_33 (Activation)     (None, 448, 448, 1)  0           ['conv2d_transpose_6[0][0]']
#
# ==================================================================================================
# Total params: 371,493
# Trainable params: 363,141
# Non-trainable params: 8,352
# __________________________________________________________________________________________________

# %%
if os.path.exists('checkpoints/enet_best_0.01815/'):
    print('weights loaded')
    model.load_weights('checkpoints/enet_best_0.01815/')

opt = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    epsilon=1e-07,
)

# loss = tf.keras.losses.BinaryCrossentropy()
loss = DiceLoss()

model.compile(
    optimizer=opt,
    loss=loss,
    # metrics=['accuracy']
)
# Out:
# weights loaded

# %%
EPOCHS = 1

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'checkpoints/enet',
    verbose=1,
    monitor='loss',
    save_best_only=True
)

lr_reduction = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='loss',
    factor=0.5,
    patience=10,
    verbose=1,
    min_delta=0.0001,
    cooldown=3,
    min_lr=1e-8,
)

model.fit(
    traingen,
    epochs=EPOCHS,
    verbose=1,
    # validation_data=valgen,
    callbacks=[checkpoint, lr_reduction]
)
# Out:
# 17/17 [==============================] - ETA: 0s - loss: 0.1745
# Epoch 1: loss improved from inf to 0.17453, saving model to checkpoints/enet
# INFO:tensorflow:Assets written to: checkpoints/enet/assets
# 17/17 [==============================] - 34s 2s/step - loss: 0.1745 - lr: 0.0010

# %%
model.load_weights('checkpoints/enet_best_0.01815/')

# %%
test = valgen.__getitem__(0)
img = test[0][8]
mask = test[1][8]

# %%
img.shape, mask.shape
# Out:
# (TensorShape([448, 448, 3]), TensorShape([448, 448, 1]))

# %%
from matplotlib import pyplot as plt
plt.imshow(img, interpolation='nearest')
plt.show()

# %%
plt.imshow(mask, cmap='gray')
plt.show()

# %%
pred = model.predict(tf.convert_to_tensor([img]))
pred = pred[0]

def fn(x):
    return 0. if x < 0.5 else 1.
fn = np.vectorize(fn)
pred = fn(pred)
# min(np.unique(pred))

# %%
plt.imshow(pred, cmap='gray')
plt.show()
